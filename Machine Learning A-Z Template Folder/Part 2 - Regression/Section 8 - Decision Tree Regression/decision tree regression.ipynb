# %%
# %matplotlib inline
# Out:
# In [16] used 0.0234 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 120.82 MiB

# %%
# Decision Tree Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# Splitting the dataset into the Training set and Test set
"""from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)"""

# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""
# Out:
# 'from sklearn.preprocessing import StandardScaler\nsc_X = StandardScaler()\nX_train = sc_X.fit_transform(X_train)\nX_test = sc_X.transform(X_test)\nsc_y = StandardScaler()\ny_train = sc_y.fit_transform(y_train)'
# In [2] used 1.1133 MiB RAM in 0.14s, peaked 0.00 MiB above current, total RAM usage 101.97 MiB

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')
# In [4] used 0.1680 MiB RAM in 0.12s, peaked 0.00 MiB above current, total RAM usage 103.49 MiB

# %%
y_pred = regressor.predict(6.5)
y_pred
# Out:
# array([ 150000.])
# In [6] used 0.0078 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 103.54 MiB

# %%
plt.scatter(X, y, color='red')
plt.plot(X, regressor.predict(X), color="blue")
plt.title("Truth or Bluff (Decision Tree Regression Model)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
# Out:
# Text(0,0.5,u'Salary')
# In [17] used 1.4883 MiB RAM in 0.25s, peaked 0.00 MiB above current, total RAM usage 122.30 MiB

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor.predict(X_grid), color="blue")
plt.title("Truth or Bluff (Decision Tree Regression Model)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
# Out:
# Text(0,0.5,u'Salary')
# In [18] used 1.6680 MiB RAM in 0.26s, peaked 0.00 MiB above current, total RAM usage 123.97 MiB
