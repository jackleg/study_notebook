# %%
# %run /data1/users/jay.han/ipython_notebook/lib/ipython_lib.py
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')
import statsmodels.api as sm

# %%
feature_two = pd.read_csv("/data1/users/jay.han/tmp/feature_two", sep="\t")
feature_two.columns = ["obj", "f1", "f2"]
feature_two.head()
# Out:
#    obj        f1        f2
# 0    5  0.163629  4.369448
# 1    5  0.003417  3.262361
# 2    5  0.014859  0.000000
# 3    5  0.056441  4.605170
# 4    5  0.025879  4.199705

# %%
feature_two.loc[:, "new_obj"] = feature_two.obj.apply(lambda score: 1 if score >= 3 else 0)
feature_two.head()
# Out:
#    obj        f1        f2  bias  new_obj
# 0    5  0.163629  4.369448     1        1
# 1    5  0.003417  3.262361     1        1
# 2    5  0.014859  0.000000     1        1
# 3    5  0.056441  4.605170     1        1
# 4    5  0.025879  4.199705     1        1

# %%
result = sm.Logit(feature_two["new_obj"], feature_two[["f1", "f2", "bias"]]).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.534501
#          Iterations 6

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                new_obj   No. Observations:                 6207
# Model:                          Logit   Df Residuals:                     6204
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 27 Oct 2015   Pseudo R-squ.:                 0.02017
# Time:                        18:55:41   Log-Likelihood:                -3317.6
# converged:                       True   LL-Null:                       -3386.0
#                                         LLR p-value:                 2.167e-30
# ...
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# f1             0.3927      0.166      2.370      0.018         0.068     0.717
# f2             0.2204      0.019     11.400      0.000         0.183     0.258
# ...

# %%
feature_two.loc[:, "predict"] = result.predict()

# %%
feature_two.predict.describe()
# Out:
# count    6207.000000
# mean        0.764782
# std         0.064860
# min         0.556025
# 25%         0.745282
# 50%         0.775994
# 75%         0.802279
# max         0.952319
# Name: predict, dtype: float64

# %%
feature_two.corr()
# Out:
#               obj        f1        f2  bias   new_obj   predict
# obj      1.000000  0.026057  0.214016   NaN  0.782008  0.201388
# f1       0.026057  1.000000  0.006045   NaN  0.032881  0.215034
# f2       0.214016  0.006045  1.000000   NaN  0.148181  0.969066
# bias          NaN       NaN       NaN   NaN       NaN       NaN
# new_obj  0.782008  0.032881  0.148181   NaN  1.000000  0.144126
# predict  0.201388  0.215034  0.969066   NaN  0.144126  1.000000

# %%
feature_two.head(n=50)
# Out:
#     obj        f1        f2  new_obj   predict
# 0     5  0.163629  4.369448        1  0.775948
# 1     5  0.003417  3.262361        1  0.705848
# 2     5  0.014859  0.000000        1  0.501632
# 3     5  0.056441  4.605170        1  0.778726
# 4     5  0.025879  4.199705        1  0.756987
# 5     5  0.002946  4.694401        1  0.778795
# 6     5  0.131576  5.575002        1  0.825062
# 7     5  0.006584  5.065304        1  0.795695
# 8     5  0.045557  6.040935        1  0.837268
# 9     5  0.009270  5.431461        1  0.811357
# 10    5  0.459885  4.016383        1  0.782072
# 11    5  0.013802  6.345285        1  0.846265
# 12    5  0.041874  4.436752        1  0.769723
# 13    5  0.050167  4.788880        1  0.786626
# 14    5  0.004728  3.258097        1  0.705730
# 15    5  0.019581  3.277145        1  0.708139
# 16    5  0.041769  5.697513        1  0.824102
# 17    5  0.167054  5.151845        1  0.810502
# 18    5  0.019545  0.000000        1  0.502146
# ...

# %%
feature_full = pd.read_csv("/data1/users/jay.han/tmp/feature_full", sep="\t")
feature_full.columns = ["obj", "f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9"]
feature_full.loc[:, "bias"] = 1.0
feature_full.head()
# Out:
#    obj        f1        f2        f3        f4        f5        f6        f7        f8        f9  bias
# 0    5  1.386294  1.386294  1.386294  1.098612  0.693147  2.512306  1.098612  0.693147  5.575949     1
# 1    5  0.048485  4.043051  4.143135  2.890372  2.397895  0.693147  1.310945  3.526361  5.643518     1
# 2    5  0.026668  1.609438  1.609438  0.000000  0.693147  1.791759  0.693147  0.693147  4.624973     1
# 3    5  0.064771  2.944439  2.944439  0.000000  2.397895  1.268511  0.798508  2.708050  4.276666     1
# 4    5  0.174353  1.609438  1.609438  0.000000  1.098612  0.693147  0.693147  1.098612  3.881564     1

# %%
feature_full.loc[:, "new_obj"] = feature_full.obj.apply(lambda score: 1 if score >= 3 else 0)
feature_full.head()
# Out:
#    obj        f1        f2        f3        f4        f5        f6        f7        f8        f9  bias  new_obj
# 0    5  1.386294  1.386294  1.386294  1.098612  0.693147  2.512306  1.098612  0.693147  5.575949     1        1
# 1    5  0.048485  4.043051  4.143135  2.890372  2.397895  0.693147  1.310945  3.526361  5.643518     1        1
# 2    5  0.026668  1.609438  1.609438  0.000000  0.693147  1.791759  0.693147  0.693147  4.624973     1        1
# 3    5  0.064771  2.944439  2.944439  0.000000  2.397895  1.268511  0.798508  2.708050  4.276666     1        1
# 4    5  0.174353  1.609438  1.609438  0.000000  1.098612  0.693147  0.693147  1.098612  3.881564     1        1

# %%
result_full = sm.Logit(feature_full["new_obj"], feature_full[["f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9", "bias"]]).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.531250
#          Iterations 6

# %%
result_full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                new_obj   No. Observations:                 6207
# Model:                          Logit   Df Residuals:                     6197
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 27 Oct 2015   Pseudo R-squ.:                 0.02613
# Time:                        18:56:54   Log-Likelihood:                -3297.5
# converged:                       True   LL-Null:                       -3386.0
#                                         LLR p-value:                 2.186e-33
# ...
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# f1             0.3430      0.158      2.164      0.030         0.032     0.654
# f2             0.3955      0.264      1.500      0.134        -0.121     0.912
# ...

# %%
feature_full.loc[:, "predict"] = result_full.predict()

# %%
feature_full.corr()
# Out:
#               obj        f1        f2        f3        f4        f5        f6        f7        f8        f9  bias   new_obj   predict
# obj      1.000000  0.026055  0.134244  0.133465  0.084489  0.146343 -0.049498 -0.052831  0.134597  0.213942   NaN  0.782008  0.219642
# f1       0.026055  1.000000  0.030326  0.034469  0.017178  0.039844  0.158346  0.044134  0.053243  0.006057   NaN  0.032880  0.191345
# f2       0.134244  0.030326  1.000000  0.996995  0.834163  0.910517 -0.244793 -0.127145  0.924695  0.380231   NaN  0.102481  0.596383
# f3       0.133465  0.034469  0.996995  1.000000  0.835425  0.911185 -0.238311 -0.121546  0.926305  0.383448   NaN  0.101766  0.592226
# f4       0.084489  0.017178  0.834163  0.835425  1.000000  0.700202 -0.043428  0.225204  0.797734  0.315689   NaN  0.062960  0.366395
# f5       0.146343  0.039844  0.910517  0.911185  0.700202  1.000000 -0.275393 -0.262348  0.936751  0.423640   NaN  0.119907  0.697798
# ...

# %%
result_linear = sm.OLS(feature_two["obj"], feature_two[["f1", "f2"]]).fit()

# %%
result_linear.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    obj   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                 1.637e+04
# Date:                Tue, 27 Oct 2015   Prob (F-statistic):               0.00
# Time:                        19:06:44   Log-Likelihood:                -10896.
# No. Observations:                6207   AIC:                         2.180e+04
# Df Residuals:                    6205   BIC:                         2.181e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# f1             0.4555      0.074      6.180      0.000         0.311     0.600
# ...

# %%
feature_two.loc[:, "predict_linear"] = result_linear.predict()

# %%
feature_two.corr()
# Out:
#                      obj        f1        f2  bias   new_obj   predict  predict_linear
# obj             1.000000  0.026057  0.214016   NaN  0.782008  0.201388        0.215434
# f1              0.026057  1.000000  0.006045   NaN  0.032881  0.215034        0.111591
# f2              0.214016  0.006045  1.000000   NaN  0.148181  0.969066        0.994411
# bias                 NaN       NaN       NaN   NaN       NaN       NaN             NaN
# new_obj         0.782008  0.032881  0.148181   NaN  1.000000  0.144126        0.150730
# predict         0.201388  0.215034  0.969066   NaN  0.144126  1.000000        0.985735
# predict_linear  0.215434  0.111591  0.994411   NaN  0.150730  0.985735        1.000000

# %%
result_full_linear = sm.OLS(feature_full["obj"], feature_full[["f1", "f2", "f3", "f4", "f5", "f6", "f7", "f8", "f9"]]).fit()

# %%
result_full_linear.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    obj   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     5807.
# Date:                Tue, 27 Oct 2015   Prob (F-statistic):               0.00
# Time:                        19:07:16   Log-Likelihood:                -9631.9
# No. Observations:                6207   AIC:                         1.928e+04
# Df Residuals:                    6198   BIC:                         1.934e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# f1             0.0648      0.062      1.052      0.293        -0.056     0.186
# ...

# %%
feature_full.loc[:, "predict_linear"] = result_full_linear.predict()

# %%
feature_full.corr()
# Out:
#                      obj        f1        f2        f3        f4        f5        f6        f7        f8        f9  bias   new_obj   predict  predict_linear
# obj             1.000000  0.026055  0.134244  0.133465  0.084489  0.146343 -0.049498 -0.052831  0.134597  0.213942   NaN  0.782008  0.219642        0.206394
# f1              0.026055  1.000000  0.030326  0.034469  0.017178  0.039844  0.158346  0.044134  0.053243  0.006057   NaN  0.032880  0.191345        0.089989
# f2              0.134244  0.030326  1.000000  0.996995  0.834163  0.910517 -0.244793 -0.127145  0.924695  0.380231   NaN  0.102481  0.596383        0.501883
# f3              0.133465  0.034469  0.996995  1.000000  0.835425  0.911185 -0.238311 -0.121546  0.926305  0.383448   NaN  0.101766  0.592226        0.500435
# f4              0.084489  0.017178  0.834163  0.835425  1.000000  0.700202 -0.043428  0.225204  0.797734  0.315689   NaN  0.062960  0.366395        0.310844
# ...
